# %% [markdown]
# <a href="https://colab.research.google.com/github/abrishkhanzai441-arch/project.py/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Temperature Converter: Celsius <-> Fahrenheit

def celsius_to_fahrenheit(celsius):
    """Convert Celsius to Fahrenheit."""
    return (celsius * 9/5) + 32

def fahrenheit_to_celsius(fahrenheit):
    """Convert Fahrenheit to Celsius."""
    return (fahrenheit - 32) * 5/9

def main():
    print("Temperature Converter")
    print("1. Celsius to Fahrenheit")
    print("2. Fahrenheit to Celsius")

    # Get user's choice of conversion
    choice = input("Choose an option (1 or 2): ")

    if choice == "1":
        celsius = float(input("Enter temperature in Celsius: "))
        fahrenheit = celsius_to_fahrenheit(celsius)
        print(f"{celsius}°C is equal to {fahrenheit:.2f}°F")

    elif choice == "2":
        fahrenheit = float(input("Enter temperature in Fahrenheit: "))
        celsius = fahrenheit_to_celsius(fahrenheit)
        print(f"{fahrenheit}°F is equal to {celsius:.2f}°C")

    else:
        print("Invalid choice. Please enter 1 or 2.")

if __name__ == "__main__":
    main()
# Out:
# Temperature Converter
# 1. Celsius to Fahrenheit
# 2. Fahrenheit to Celsius
# Choose an option (1 or 2): 1
# Enter temperature in Celsius: 25
# 25.0°C is equal to 77.00°F

# %%
# Menu-Driven Calculator

def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    # Handle division by zero
    if b == 0:
        return "Error: Cannot divide by zero"
    return a / b

def main():
    while True:  # Loop keeps the calculator running until user exits
        print("\n----- Menu-Driven Calculator -----")
        print("1. Addition (+)")
        print("2. Subtraction (-)")
        print("3. Multiplication (×)")
        print("4. Division (÷)")
        print("5. Exit")

        choice = input("Choose an operation (1-5): ")

        # Exit option handled first so we don't ask for numbers unnecessarily
        if choice == "5":
            print("Exiting calculator. Goodbye!")
            break

        # Validate menu choice before asking for numbers
        if choice not in ("1", "2", "3", "4"):
            print("Invalid choice. Please select a number between 1 and 5.")
            continue

        # Get the two numbers to operate on
        try:
            num1 = float(input("Enter the first number: "))
            num2 = float(input("Enter the second number: "))
        except ValueError:
            print("Invalid input. Please enter numeric values.")
            continue

        # Perform the chosen operation
        if choice == "1":
            result = add(num1, num2)
            print(f"Result: {num1} + {num2} = {result}")
        elif choice == "2":
            result = subtract(num1, num2)
            print(f"Result: {num1} - {num2} = {result}")
        elif choice == "3":
            result = multiply(num1, num2)
            print(f"Result: {num1} × {num2} = {result}")
        elif choice == "4":
            result = divide(num1, num2)
            print(f"Result: {num1} ÷ {num2} = {result}")

if __name__ == "__main__":
    main()
# Out:
# ----- Menu-Driven Calculator -----
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (×)
# 4. Division (÷)
# 5. Exit
# Choose an operation (1-5): 2
# Enter the first number: 54
# Enter the second number: 8
# Result: 54.0 - 8.0 = 46.0
#
# ----- Menu-Driven Calculator -----
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (×)
# 4. Division (÷)
# 5. Exit
# Choose an operation (1-5): 1
# Enter the first number: 87
# Enter the second number: 6
# Result: 87.0 + 6.0 = 93.0
#
# ----- Menu-Driven Calculator -----
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (×)
# 4. Division (÷)
# 5. Exit
# Choose an operation (1-5): 3
# Enter the first number: 78
# Enter the second number: 8
# Result: 78.0 × 8.0 = 624.0
#
# ----- Menu-Driven Calculator -----
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (×)
# 4. Division (÷)
# 5. Exit
# Choose an operation (1-5): *
# Invalid choice. Please select a number between 1 and 5.
#
# ----- Menu-Driven Calculator -----
# ...

# %%
# Simple Calculator Program

# Take input numbers from the user
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

# Display the operation menu
print("\nSelect an operation:")
print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")

# Take the user's choice
choice = input("Enter your choice (1/2/3/4): ")

# Perform the selected operation and display the result
if choice == "1":
    result = num1 + num2
    print(f"Result: {num1} + {num2} = {result}")
elif choice == "2":
    result = num1 - num2
    print(f"Result: {num1} - {num2} = {result}")
elif choice == "3":
    result = num1 * num2
    print(f"Result: {num1} × {num2} = {result}")
elif choice == "4":
    if num2 == 0:
        print("Error: Cannot divide by zero")
    else:
        result = num1 / num2
        print(f"Result: {num1} ÷ {num2} = {result}")
else:
    print("Invalid choice. Please select 1, 2, 3, or 4.")
# Out:
# Enter the first number: 68
# Enter the second number: 8
#
# Select an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Enter your choice (1/2/3/4): 2
# Result: 68.0 - 8.0 = 60.0

# %%
print('''"temperature converter
  1.celsius to fahrenheit
  2.fahrenheit to celsius"''')

if choice=="1":
  celsius_tem

# %%
"""
Student Gradebook Application
------------------------------
A simple console-based program that stores and manages student marks
using a CSV file. Supports adding students, viewing all records,
searching by name, and calculating grades.
"""

import csv
import os

# Name of the CSV file used to store student records
FILENAME = "students.csv"

# Column headers for the CSV file
FIELDNAMES = ["Name", "Marks", "Grade"]


def calculate_grade(marks):
    """
    Calculate a letter grade based on numeric marks (out of 100).
    Raises ValueError if marks are out of the valid 0-100 range.
    """
    if marks < 0 or marks > 100:
        raise ValueError("Marks must be between 0 and 100.")

    if marks >= 90:
        return "A"
    elif marks >= 80:
        return "B"
    elif marks >= 70:
        return "C"
    elif marks >= 60:
        return "D"
    elif marks >= 50:
        return "E"
    else:
        return "F"


def initialize_file():
    """
    Create the CSV file with headers if it does not already exist.
    """
    if not os.path.exists(FILENAME):
        try:
            with open(FILENAME, mode="w", newline="") as file:
                writer = csv.DictWriter(file, fieldnames=FIELDNAMES)
                writer.writeheader()
        except IOError as e:
            print(f"Error creating file: {e}")


def add_student():
    """
    Prompt the user for a student's name and marks, calculate the grade,
    and append the record to the CSV file.
    """
    try:
        name = input("Enter student name: ").strip()
        if not name:
            print("Error: Name cannot be empty.")
            return

        marks_input = input("Enter student marks (0-100): ").strip()
        marks = float(marks_input)  # may raise ValueError if not numeric

        grade = calculate_grade(marks)  # may raise ValueError if out of range

        with open(FILENAME, mode="a", newline="") as file:
            writer = csv.DictWriter(file, fieldnames=FIELDNAMES)
            writer.writerow({"Name": name, "Marks": marks, "Grade": grade})

        print(f"Student '{name}' added successfully with grade '{grade}'.")

    except ValueError as e:
        # Handles both invalid numeric input and out-of-range marks
        print(f"Invalid input: {e}")
    except IOError as e:
        print(f"File error while saving student: {e}")


def view_students():
    """
    Read and display all student records from the CSV file.
    Handles the case where the file is missing or empty.
    """
    try:
        with open(FILENAME, mode="r", newline="") as file:
            reader = csv.DictReader(file)
            records = list(reader)

            if not records:
                print("No student records found.")
                return

            print("\n{:<20} {:<10} {:<10}".format("Name", "Marks", "Grade"))
            print("-" * 40)
            for row in records:
                print("{:<20} {:<10} {:<10}".format(
                    row["Name"], row["Marks"], row["Grade"]))

    except FileNotFoundError:
        print("Error: No records file found yet. Please add a student first.")
    except IOError as e:
        print(f"Error reading file: {e}")


def search_student():
    """
    Search for a student by name (case-insensitive) and display their
    marks and grade if found.
    """
    try:
        search_name = input("Enter student name to search: ").strip().lower()

        with open(FILENAME, mode="r", newline="") as file:
            reader = csv.DictReader(file)
            found = False

            for row in reader:
                if row["Name"].strip().lower() == search_name:
                    print(f"\nName: {row['Name']}")
                    print(f"Marks: {row['Marks']}")
                    print(f"Grade: {row['Grade']}")
                    found = True
                    break

            if not found:
                print(f"No record found for student '{search_name}'.")

    except FileNotFoundError:
        print("Error: No records file found yet. Please add a student first.")
    except IOError as e:
        print(f"Error reading file: {e}")


def display_menu():
    """Display the main menu options to the user."""
    print("\n===== Student Gradebook Menu =====")
    print("1. Add Student")
    print("2. View Student Records")
    print("3. Search Student")
    print("4. Exit")


def main():
    """Main program loop that drives the gradebook application."""
    initialize_file()

    while True:
        display_menu()
        choice = input("Enter your choice (1-4): ").strip()

        if choice == "1":
            add_student()
        elif choice == "2":
            view_students()
        elif choice == "3":
            search_student()
        elif choice == "4":
            print("Exiting Gradebook Application. Goodbye!")
            break
        else:
            print("Invalid choice. Please enter a number between 1 and 4.")


# Entry point of the program
if __name__ == "__main__":
    main()
# Out:
# ===== Student Gradebook Menu =====
# 1. Add Student
# 2. View Student Records
# 3. Search Student
# 4. Exit
# Enter your choice (1-4): 1
# Enter student name: ali
# Enter student marks (0-100): 67
# Student 'ali' added successfully with grade 'D'.
#
# ===== Student Gradebook Menu =====
# 1. Add Student
# 2. View Student Records
# 3. Search Student
# 4. Exit
# Enter your choice (1-4): 2
#
# Name                 Marks      Grade
# ----------------------------------------
# ali                  67.0       D
#
# ===== Student Gradebook Menu =====
# 1. Add Student
# 2. View Student Records
# 3. Search Student
# 4. Exit
# Enter your choice (1-4): 3
# Enter student name to search: ali
#
# Name: ali
# Marks: 67.0
# Grade: D
#
# ===== Student Gradebook Menu =====
# 1. Add Student
# 2. View Student Records
# 3. Search Student
# 4. Exit
# Enter your choice (1-4): 3
# Enter student name to search: ali
#
# Name: ali
# Marks: 67.0
# Grade: D
#
# ===== Student Gradebook Menu =====
# 1. Add Student
# ...

# %%
"""
Currency Converter using the exchangerate-api.com free API

Week 8 Assignment: Build a Currency Converter Using an Exchange Rate API
"""

import requests

# Free, no-API-key-required endpoint (open.er-api.com).
# It returns the latest exchange rates for a given base currency.
BASE_URL = "https://open.er-api.com/v6/latest/"


def get_exchange_rate(source_currency, target_currency):
    """
    Fetch the exchange rate from source_currency to target_currency.

    Returns the rate as a float, or None if something went wrong
    (invalid currency code, network error, bad response, etc.)
    """
    url = BASE_URL + source_currency.upper()

    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()  # raises an error for 4xx/5xx status codes
    except requests.exceptions.RequestException as e:
        print(f"Error: Could not connect to the exchange rate API. ({e})")
        return None

    # Parse the JSON body of the response
    data = response.json()

    # The API returns "result": "error" if the base currency code is invalid
    if data.get("result") != "success":
        print("Error: Invalid source currency code or API returned an error.")
        return None

    rates = data.get("rates", {})
    target_currency = target_currency.upper()

    if target_currency not in rates:
        print("Error: Invalid target currency code.")
        return None

    return rates[target_currency]


def get_user_input():
    """
    Prompt the user for the source currency, target currency, and amount.
    Returns a tuple (source, target, amount) or None if the amount is invalid.
    """
    source_currency = input("Enter source currency (e.g., USD): ").strip().upper()
    target_currency = input("Enter target currency (e.g., EUR): ").strip().upper()

    try:
        amount = float(input("Enter the amount to convert: ").strip())
    except ValueError:
        print("Error: Amount must be a number.")
        return None

    if amount < 0:
        print("Error: Amount cannot be negative.")
        return None

    return source_currency, target_currency, amount


def convert_currency(amount, rate):
    """Calculate the converted amount given the amount and exchange rate."""
    return amount * rate


def main():
    """Main program loop: get input, fetch rate, convert, and display result."""
    user_data = get_user_input()

    # Stop early if the amount input was invalid
    if user_data is None:
        return

    source_currency, target_currency, amount = user_data

    rate = get_exchange_rate(source_currency, target_currency)

    # Stop early if the exchange rate could not be retrieved
    if rate is None:
        return

    converted_amount = convert_currency(amount, rate)

    print("\n--- Conversion Result ---")
    print(f"Exchange rate: 1 {source_currency} = {rate} {target_currency}")
    print(f"{amount} {source_currency} = {converted_amount:.2f} {target_currency}")


if __name__ == "__main__":
    main()
# Out:
# Enter source currency (e.g., USD): USD
# Enter target currency (e.g., EUR): EUR
# Enter the amount to convert: 5666009
#
# --- Conversion Result ---
# Exchange rate: 1 USD = 0.86671 EUR
# 5666009.0 USD = 4910786.66 EUR

# %%
class Student:
    """Base class representing a general student."""
    def __init__(self, student_id, name, age, course):
        self.student_id = student_id
        self.name = name
        self.age = age
        self.course = course

    def display_info(self):
        """Displays student details."""
        return (f"ID: {self.student_id} | Name: {self.name} | "
                f"Age: {self.age} | Course: {self.course}")


class GraduateStudent(Student):
    """Subclass demonstrating inheritance and method overriding."""
    def __init__(self, student_id, name, age, course, thesis_topic):
        super().__init__(student_id, name, age, course)
        self.thesis_topic = thesis_topic

    # Method Overriding
    def display_info(self):
        """Overrides base class method to include thesis info."""
        base_info = super().display_info()
        return f"{base_info} | Thesis: {self.thesis_topic}"


class StudentManagementSystem:
    """Class to manage multiple students."""
    def __init__(self):
        self.students = {}

    def add_student(self):
        """Adds a new student to the system."""
        student_id = input("Enter Student ID: ")
        if student_id in self.students:
            print("Error: Student ID already exists.")
            return

        name = input("Enter Name: ")
        age = input("Enter Age: ")
        course = input("Enter Course/Program: ")
        is_grad = input("Is this a graduate student? (y/n): ").lower()

        if is_grad == 'y':
            thesis = input("Enter Thesis Topic: ")
            student = GraduateStudent(student_id, name, age, course, thesis)
        else:
            student = Student(student_id, name, age, course)

        self.students[student_id] = student
        print("Student added successfully!")

    def update_student(self):
        """Updates an existing student's information using Student ID."""
        student_id = input("Enter Student ID to update: ")
        if student_id not in self.students:
            print("Error: Student ID not found.")
            return

        print("Leave field blank if you do not want to change it.")
        name = input("Enter new Name: ")
        age = input("Enter new Age: ")
        course = input("Enter new Course/Program: ")

        student = self.students[student_id]
        if name:
            student.name = name
        if age:
            student.age = age
        if course:
            student.course = course

        print("Student updated successfully!")

    def view_students(self):
        """Displays all registered students."""
        if not self.students:
            print("No students registered yet.")
            return

        print("\n--- Registered Students ---")
        for student in self.students.values():
            print(student.display_info())
        print("-" * 27)


def main():
    system = StudentManagementSystem()
    while True:
        print("\n=== Student Management System ===")
        print("1. Add Student")
        print("2. Update Student")
        print("3. View Students")
        print("4. Exit")

        choice = input("Enter your choice (1-4): ")

        if choice == '1':
            system.add_student()
        elif choice == '2':
            system.update_student()
        elif choice == '3':
            system.view_students()
        elif choice == '4':
            print("Exiting program. Goodbye!")
            break
        else:
            print("Invalid choice. Please enter a number from 1 to 4.")

if __name__ == "__main__":
    main()
# Out:
# === Student Management System ===
# 1. Add Student
# 2. Update Student
# 3. View Students
# 4. Exit
# Enter your choice (1-4): 1064
# Invalid choice. Please enter a number from 1 to 4.
#
# === Student Management System ===
# 1. Add Student
# 2. Update Student
# 3. View Students
# 4. Exit
# Enter your choice (1-4): 1234
# Invalid choice. Please enter a number from 1 to 4.
#
# === Student Management System ===
# 1. Add Student
# 2. Update Student
# 3. View Students
# 4. Exit
# Enter your choice (1-4): 1
# Enter Student ID: 10943
# Enter Name: ali
# Enter Age: 23
# Enter Course/Program: python
# Is this a graduate student? (y/n): no
# Student added successfully!
#
# === Student Management System ===
# 1. Add Student
# 2. Update Student
# 3. View Students
# 4. Exit
# Enter your choice (1-4): 2
# Enter Student ID to update: 45362
# Error: Student ID not found.
#
# === Student Management System ===
# 1. Add Student
# 2. Update Student
# 3. View Students
# 4. Exit
# ...

# %%
menu = """========== CONTACT BOOK ==========

1. Add Contact
2. Search Contact
3. View Contacts
4. Exit"""

contacts = {
    "users":[

    ]
}

def add_contact():
  name = input("Enter your name:")
  num = int(input("Enter your number:"))
  email = input("Enter your email:")
  contacts["users"].append({"name":name,"number":num,"email":email})

def search_contact():
  search = input("Enter the name to search:")
  found = False
  for i in contacts["users"]:
    if search in i["name"]:
      print("Name:",i["name"])
      print("Number:",i["number"])
      print("Email:",i["email"])
      found = True
  if found is False:
    print("Contact not found")

def view_contact():
  for i in contacts["users"]:
    print("***All Saved Contacts***")
    print("Name:",i["name"])
    print("Number:",i["number"])
    print("Email:",i["email"])

choice = 0
while choice != 4:
  print(menu)
  choice = int(input("Enter your choice:"))
  if choice == 1:
    add_contact()
  elif choice == 2:
    search_contact()
  elif choice == 3:
    view_contact()
  elif choice == 4:
    print("Exit!")
  else:
    print("Invalid choice.")
# Out:
# ========== CONTACT BOOK ==========
#
# 1. Add Contact
# 2. Search Contact
# 3. View Contacts
# 4. Exit
# Enter your choice:1
# Enter your name:ali
# Enter your number:456789043
# Enter your email:adhuy@gmail.com
# ========== CONTACT BOOK ==========
#
# 1. Add Contact
# 2. Search Contact
# 3. View Contacts
# 4. Exit
# Enter your choice:2
# Enter the name to search:ali
# Name: ali
# Number: 456789043
# Email: adhuy@gmail.com
# ========== CONTACT BOOK ==========
#
# 1. Add Contact
# 2. Search Contact
# 3. View Contacts
# 4. Exit
# Enter your choice:3
# ***All Saved Contacts***
# Name: ali
# Number: 456789043
# Email: adhuy@gmail.com
# ========== CONTACT BOOK ==========
#
# 1. Add Contact
# 2. Search Contact
# 3. View Contacts
# 4. Exit
# Enter your choice:3
# ***All Saved Contacts***
# Name: ali
# Number: 456789043
# Email: adhuy@gmail.com
# ========== CONTACT BOOK ==========
#
# 1. Add Contact
# 2. Search Contact
# 3. View Contacts
# 4. Exit
# Enter your choice:4
# Exit!

# %%
ice=int(input("enter your num" ))
coco=int(input("enter your num" ))
operator=input ("enter operator (+,-,*,%)")
if operator=="+":
  print(ice + coco)
elif operator=="-":
    print(ice - coco)
elif operator=="*":
      print(ice * coco)
elif operator=="%":
        print(ice % coco)
else:
  print("invalid operator")
# Out:
# enter your num67
# enter your num7
# enter operator (+,-,*,%)-
# 60

# %%
# number=int(input("enter father cnic"))
# def num (weight):
#   print("your father cnic i", number)
#   print("weight", weight)
# num(weight)

# %%
# a=int(input("enter your num"))
# def b():
#   if a % 2==0
#   print("it is even")
#   else:
#     print("it is odd")
# b()

# %%
num=int(input("enter your num"))
if num % 2==0:
  print (f"{num} is even")
else:
  print (f"{num} is odd")

# %%
# things=["pencil","chair","table","pen","book","ink"]
# print[things]
# print(things["3"])
# things.append("cloth")
# print(things)
# things.remove("box")
# print(things)
# things.modify
# print(len(things))

# %%
# fruit=["mango","strawberry","blueberry","grapes"]
# print=(fruit)

# %%
# dictionary={"title","the hell","price","500","author","M.william"}
# print=(dictionary["title"])
# title

# %%
# name= (input("enter your name"))
# age=int(input("enter your  age"))
# city=(input("enter your city"))
# dic= {"student":student ,"age":age,"city":city}
# print=(dic)

# %%
# student=[
#     {"name":"ali","age":17,"city":"hyd"},
#     {"name":"ahmed","age":23,"city":"karachi"},
#     {"name":"raza","age":22,"city":"kpk" },
#     {"name":"bilal","age":33,"city":"balochistan"}
# ]

# for i in student:
#   print(i["name"])
# for i in student:
#   print(i["age"])
# for i in student:
#   print(i["city"])
# Out:
# ali
# ahmed
# raza
# bilal
# 17
# 23
# 22
# 33
# hyd
# karachi
# kpk
# balochistan

# %%
import requests
def convert_currency():
  source=input("enter source currency")
  target=input("enter target")

# %%
# try:
#    num=int(input("enter your num :"))
#  print(10/num)
# except:
#     print("something went wrong")
# else:
#     print("your program run sucessfuly with no error")
# finally:
#    print("finally finished")
# Out:
#   File "<tokenize>", line 3
#     print(10/num)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# try:
#   num=int(input("enter  your num:"))
#   print(10/num)
# except:
#   print("something went wrong")
# else:
#     print("your program run sucessfully with no error")
# finally:
#   print("finally finished")
# Out:
# enter  your num:24
# 0.4166666666666667
# your program run sucessfully with no error
# finally finished

# %%
# try:
#   num=int(input("enter your num"))
#   print(num)
# except:
#   print("if the user inter letter or invailed num the program display an error ")
# else:
#   print("if no error display transaction successfull")
# finally:
#   print("thankyou for using our ATM")
# Out:
# enter your num20000
# 20000
# if no error display transaction successfull
# thankyou for using our ATM

# %%
# oop
# class student:
#  pass
# print(student)

# %%
# class sttudent:
#  print(student)
# Out:
# <class '__main__.student'>

# %%
# class student:
#   pass
# std1=student()
# std2=student()
# print(std1)
# print(std2)

# %%
# class ali:
#   class table:
#    pass
# st1 = ali()
# st2 = ali.table()
# print(st1)
# print(st2)

# %%
# class student:
#   class car:
#     pass

# std1=student()
# std2= student.car()
# print(std1)
# print(std2)

# %%
# class name:
#   name="ali"
#   age=12
# s1=name()
# s2=()
# print(s1.name)
# print(s1.age)
# Out:
# ali
# 12

# %%
class employe:
  name="ali"
  salary=10000 # Corrected to an integer

# Create instances outside the class definition
e1 = employe()
e2 = employe()

print(e1.name)
print(e2.salary)
# Out:
# ali
# 10000

# %%
class ATM:
  def __init__(self,name,amount):
    self.name =name
    self.amount=amount
obj1=ATM("sara",500)
print(obj1.name)
print(obj1.amount)
# Out:
# sara
# 500

# %%
class program:
  def __init__(self, name, age):
     self.name = name
     self.age = age
ob1 = program("ali", 22)
print(ob1.name)
print(ob1.age)
# Out:
# ali
# 22

# %%
class pro:
  def __init__(self, name, age):
    self.name = name
    self.age = age
ob1 = pro("ali",23)
print(ob1.name)
print(ob1.age)
# Out:
# ali
# 23

# %%
class book:
  def __init__(self,author,price,page):
    self.author=author
    self.price=price
    self.page=page
ob1=book("rubab",1000,200)
print(ob1.author)
print(ob1.price)
print(ob1.page)
# Out:
# rubab
# 1000
# 200

# %%
from os.path import splitdrive
class movie:
  def __init__(self,spider):
    self.spider=spider # Changed to store the passed argument
    # Example of creating an instance (assuming 'man' is a string)
    # ob = movie("some_path_component")
    # print(ob.spider)

# To make the code runnable without further errors, let's provide a definition for 'man' and correct 'Ob'
man_path = "C:\\Users\\man\\documents"
ob = movie(man_path)
print(ob.spider) # Corrected 'Ob' to 'ob'
# Out:
# C:\Users\man\documents

# %%
a=10
b=20
a,b=b,a
print("a=",a)
print("b=",b)
# Out:
# a= 20
# b= 10

# %%
num = -6 # Example: Assign a negative integer
if num > 0:
  print("POSITIVE")
elif num == 0:
  print ("zero")
else:
  print("negative")
# Out:
# negative

# %%
a,b,c=12,78,45
lagest=max(a,b,c)
print("largestnum:",lagest)
# Out:
# largestnum: 78

# %%
import requests
print()

# %%
# !pip install request
# Out:
# ERROR: Could not find a version that satisfies the requirement request (from versions: none)
# ERROR: No matching distribution found for request

# %%
# !pip shows ..help
# Out:
# ERROR: unknown command "shows" - maybe you meant "show"

# %%
# !pip list
# Out:
# Package                               Version
# ------------------------------------- ------------------
# absl-py                               1.4.0
# accelerate                            1.14.0
# access                                1.1.10.post3
# affine                                2.4.0
# aiofiles                              25.1.0
# aiohappyeyeballs                      2.7.1
# aiohttp                               3.14.1
# aiosignal                             1.4.0
# aiosqlite                             0.22.1
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.8
# ale-py                                0.12.0
# altair                                5.5.0
# annotated-doc                         0.0.4
# annotated-types                       0.7.0
# antlr4-python3-runtime                4.9.3
# anyio                                 4.14.2
# anywidget                             0.9.21
# ...

# %%
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.4
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: certifi, charset_normalizer, idna, urllib3
# Required-by: bigframes, CacheControl, community, datasets, diffusers, earthengine-api, fastai, folium, gcsfs, gdown, geemap, geocoder, google-adk, google-api-core, google-cloud-bigquery, google-cloud-storage, google-colab, google-genai, googledrivedownloader, jupyter_kernel_gateway, kaggle, kagglehub, kagglesdk, keyrings.google-artifactregistry-auth, langsmith, libpysal, moviepy, music21, opentelemetry-resourcedetector-gcp, pandas-datareader, panel, pooch, pyiceberg, pysal, quantecon, requests-oauthlib, requests-toolbelt, spacy, spanner-graph-notebook, Sphinx, tensorflow, tensorflow-datasets, tiktoken, torchdata, tsfresh, tweepy, wandb, yfinance

# %%
import requests
city =input ("enter your city :")
api_key ="9f1021037b46dbc1c428344dbdfbdd53"
url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&unitsmetric"

response = requests.get(url)
print(response.json())

data = response.json()

print("city:",data["name"])
print("Temperature:", data["main"]["temp"], "c")
print("humidity:",data ["main"]["humidity"], "%")
print("weather:",data ["weather"][0]["description"])

# print(response.json())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_680/3472107869.py in <cell line: 0>()
#       1 import requests
# ----> 2 city =input ("enter your city :")
#       3 api_key ="9f1021037b46dbc1c428344dbdfbdd53"
#       4 url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&unitsmetric"
#       5
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
def add_(contacts):
  name=input("enter your name:")
  phone=input("enter phone num:")
  email=input("enter enmail adddress:")
  if name in contacts:
   print(f"contact'{name}'already exists.it will be updated.")

  contacts[name]={"phone":phone,"email":email}
  print(f"contact'{name}'add successfully")

def search_contact(contacts):
  name=input("enter name to search:")
  if  name in contacts:
    print('contact found')
    print(f"name:{name}")
    print(f"phone:{contacts[name]['phone']}")
    print(f"email:{contacts[name]['email']}")
  else:
    print(f"contact'{name}'does not exist")


def view_contacts(contacts):
    # display all saved contacts
    if not contacts:
        print("No contacts saved yet")
    else:
        print("ALL contacts")
        for name, info in contacts.items():
            print(f"Name: {name}")
            print(f"Phone: {info['phone']}")
            print(f"Email: {info['email']}\n")
def main():
  """Main program loop."""
  while True:
   show_menu()
   choice = input("Enter your choice (1-4): ").strip()
while True
show_menu()
 choice = input("Enter your choice (1-4): ").strip()

if choice == "1":
  add_contact()
         elif choice == "2":
            search_contact()
        elif choice == "3":
            view_contacts()
        elif choice == "4":
            print("Exiting Contact Book. Goodbye!")
            break
        else:
            print("Invalid choice. Please enter a number between 1 and 4.\n")


if __name__ == "__main__":
    main()
# Out:
#   File "<tokenize>", line 45
#     elif choice == "3":
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
def add_contact():
  name=input("enter your name:").strip()
  if name in contacts:
    print(f"A contact")
    return

# %%
def add_contact():

    name = input("Enter contact name: ").strip()

    if name in contacts:
        print(f"A contact named '{name}' already exists. Use a different name or update manually.")
        return

    phone = input("Enter phone number: ").strip()
    email = input("Enter email address: ").strip()

    # store phone and email as a tuple (fixed pair of values for one contact)
    contacts[name] = (phone, email)
    print(f"Contact '{name}' added successfully!\n")


def search_contact():
    """Search for a contact by name and display their details."""
    name = input("Enter the name to search: ").strip()

    if name in contacts:
        phone, email = contacts[name]
        print(f"\nName: {name}")
        print(f"Phone: {phone}")
        print(f"Email: {email}\n")
    else:
        print(f"No contact found with the name '{name}'.\n")


def view_contacts():
    """Display all saved contacts."""
    if not contacts:
        print("No contacts saved yet.\n")
        return

    print("\n--- All Contacts ---")
    # sort names alphabetically for a clean display (list of names)
    for name in sorted(contacts.keys()):
        phone, email = contacts[name]
        print(f"Name: {name} | Phone: {phone} | Email: {email}")
    print("--------------------\n")


def show_menu():
    """Display the main menu options."""
    print("===== CONTACT BOOK =====")
    print("1. Add Contact")
    print("2. Search Contact")
    print("3. View Contacts")
    print("4. Exit")


def main():
    """Main program loop."""
    while True:
        show_menu()
        choice = input("Enter your choice (1-4): ").strip()

        if choice == "1":
            add_contact()
        elif choice == "2":
            search_contact()
        elif choice == "3":
            view_contacts()
        elif choice == "4":
            print("Exiting Contact Book. Goodbye!")
            break
        else:
            print("Invalid choice. Please enter a number between 1 and 4.\n")


# if __name__ == "__main__":
#     main()

# %%
pip install opencv-python

# %%
MobileNetSSD_deploy.prototxt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3592/1730552677.py in <cell line: 0>()
# ----> 1 MobileNetSSD_deploy.prototxt
#
# NameError: name 'MobileNetSSD_deploy' is not defined
